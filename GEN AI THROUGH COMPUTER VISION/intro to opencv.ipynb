# %% [markdown]
# # INTRODUCE TO OPENCV  & IMAGE PROCESSING
#
# - https://opencv.org/
# - pip install opencv-python (python installation)

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import cv2

# %%
img =  cv2.imread(r'c:\Users\mirza\Desktop\naveed photos\IMG_20251120_170524927.jpg')

#imread never gives you error even though you mention any image

# %%
type(img) # as we define incorret  image thats why type is none type
# Out:
# numpy.ndarray

# %%
img =  cv2.imread(r'c:\Users\mirza\Desktop\naveed photos\IMG_20251120_170524927.jpg')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (4096, 1842, 3)

# %%
plt.imshow(img)

# if you notice below image actual image is different then imshow image because opencv read the image as BGR

# %%
img
# Out:
# array([[[246, 227, 206],
#         [246, 227, 206],
#         [243, 226, 205],
#         ...,
#         [240, 221, 200],
#         [239, 220, 199],
#         [239, 220, 199]],
#
#        [[246, 227, 206],
#         [246, 227, 206],
#         [244, 227, 206],
#         ...,
#         [239, 220, 199],
#         [239, 220, 199],
#         [239, 220, 199]],
#
#        [[244, 227, 206],
#         [244, 227, 206],
#         [245, 228, 207],
#         ...,
#         [239, 220, 199],
#         [239, 220, 199],
#         [239, 220, 199]],
#
#        ...,
#
#        [[174, 200, 224],
#         [172, 198, 222],
#         [171, 198, 219],
#         ...,
#         [ 78,  81,  85],
#         [ 77,  82,  85],
#         [ 76,  81,  84]],
#
#        [[171, 196, 222],
#         [168, 194, 218],
#         [169, 196, 217],
#         ...,
#         [ 89,  92,  96],
#         [ 86,  89,  93],
#         [ 83,  86,  90]],
#
#        [[170, 195, 221],
#         [167, 193, 217],
#         [167, 194, 215],
#         ...,
#         [100, 103, 107],
#         [ 96,  99, 103],
#         [ 91,  94,  98]]], dtype=uint8)

# %% [markdown]
# - matplotlibe channel--> Always give the channel ( R G B) || red, green, blue
# - opencv channel --> (B G R) || blue , green , red

# %%
fix_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(fix_img)

# %%
img_gray = cv2.imread(r'c:\Users\mirza\Desktop\naveed photos\IMG_20251120_170524927.jpg',cv2.IMREAD_GRAYSCALE)

# %%
img_gray.shape # it dont have 3 channel now
# Out:
# (4096, 1842)

# %%
img_gray
# Out:
# array([[223, 223, 222, ..., 217, 216, 216],
#        [223, 223, 223, ..., 216, 216, 216],
#        [223, 223, 224, ..., 216, 216, 216],
#        ...,
#        [204, 202, 201, ...,  82,  82,  81],
#        [201, 198, 199, ...,  93,  90,  87],
#        [200, 197, 197, ..., 104, 100,  95]], dtype=uint8)

# %%
img_gray.min()
# Out:
# 8

# %%
img_gray.max()
# Out:
# 250

# %%
plt.imshow(img_gray)

# %%
plt.imshow(img_gray, cmap='gray')

# %%
plt.imshow(img_gray, cmap = 'magma') # try with green

# %%
#plt.imshow(img_gray, cmap = 'green')
plt.imshow(img_gray, cmap = 'Accent')

# %%
plt.imshow(img)

# %%
plt.imshow(fix_img)

# %%
fix_img.shape
# Out:
# (4096, 1842, 3)

# %%
fix_img_1 = cv2.resize(fix_img,(600,500)) # 600 -width & 500- height

# %%
plt.imshow(fix_img_1)

# %%
fix_img.shape
# Out:
# (4096, 1842, 3)

# %%
w_ratio = 0.3
h_ratio = 0.3

# %%
fix_img_2 = cv2.resize(fix_img,(0,0), fix_img, w_ratio, h_ratio)

# %%
fix_img_2.shape # 50% of the fix_img shape
# Out:
# (1229, 553, 3)

# %%
plt.imshow(fix_img_2)

# %%
plt.imshow(fix_img)

# %%
img3 = cv2.flip(fix_img_2,0)
plt.imshow(img3)

# %%
cv2.imwrite('new generate image.jpg',img3)
# Out:
# True
