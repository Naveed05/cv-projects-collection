# %% [markdown]
# # INTRODUCE TO OPENCV  & IMAGE PROCESSING
#
# - https://opencv.org/
# - pip install opencv-python (python installation)

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import cv2

# %%
# # img = cv2.imread(r'C:\Users\mirza\Desktop\videos\horse.jpg')
# # or
# # img = cv2.imread(r'C:\Users\mirza\Desktop\videos\horse.jpeg')
# # # or
# # img = cv2.imread(r'C:\Users\mirza\Desktop\videos\horse.png')
# # # or
# img = cv2.imread(r'C:\Users\mirza\Desktop\videos\horse.JPG')

import cv2
import matplotlib.pyplot as plt

paths = [
    r"C:\Users\mirza\Desktop\videos\horse.jpg",
    r"C:\Users\mirza\Desktop\videos\horse.jpeg",
    r"C:\Users\mirza\Desktop\videos\horse.JPG",
    r"C:\Users\mirza\Desktop\videos\horse.PNG",
    r"C:\Users\mirza\Desktop\videos\horse.png"
]

img = None
for p in paths:
    img = cv2.imread(p)
    if img is not None:
        print("Loaded:", p)
        break

if img is None:
    print("❌ Image still not loaded. Upload the file here.")
else:
    img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    plt.imshow(img_rgb)
    plt.axis("off")
    plt.show()
# Out:
# Loaded: C:\Users\mirza\Desktop\videos\horse.jpeg

# %%
type(img) # as we define incorret  image thats why type is none type
# Out:
# numpy.ndarray

# %%
# img =  cv2.imread(r'C:\Users\A3MAX SOFTWARE TECH\Desktop\WORK\1. KODI WORK\1. NARESH\10. WORKSHOP\8. Exploring Generative AI through computer vision\elephant 1.jpg')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
# img.shape()

# %%
print(type(img))
print(img)
# Out:
# <class 'numpy.ndarray'>
# [[[ 22  14  15]
#   [ 37  27  27]
#   [ 73  59  53]
#   ...
#   [246 223 201]
#   [246 223 201]
#   [246 223 201]]
#
#  [[ 28  20  20]
#   [ 35  26  23]
#   [ 62  49  41]
#   ...
#   [245 222 200]
#   [245 222 200]
#   [245 222 200]]
#
#  [[ 31  25  20]
#   [ 38  30  23]
#   [ 58  48  38]
#   ...
#   [245 222 200]
#   [245 222 200]
#   [245 222 200]]
#
#  ...
#
#  [[ 90 168 174]
#   [102 180 186]
#   [112 190 196]
#   ...
#   [ 74 149 147]
#   [ 81 156 154]
#   [ 98 173 171]]
#
#  [[ 92 170 176]
#   [ 99 180 185]
#   [114 195 200]
#   ...
#   [ 58 133 131]
#   [ 50 125 123]
#   [ 68 143 141]]
#
#  [[ 90 171 174]
#   [ 86 169 171]
#   [107 190 192]
#   ...
#   [ 75 150 148]
#   [ 57 132 130]
#   [ 92 167 165]]]

# %%
plt.imshow(img)
# if you notice below image actual image is different then imshow image because opencv read the image as BGR

# %%
img
# Out:
# array([[[ 22,  14,  15],
#         [ 37,  27,  27],
#         [ 73,  59,  53],
#         ...,
#         [246, 223, 201],
#         [246, 223, 201],
#         [246, 223, 201]],
#
#        [[ 28,  20,  20],
#         [ 35,  26,  23],
#         [ 62,  49,  41],
#         ...,
#         [245, 222, 200],
#         [245, 222, 200],
#         [245, 222, 200]],
#
#        [[ 31,  25,  20],
#         [ 38,  30,  23],
#         [ 58,  48,  38],
#         ...,
#         [245, 222, 200],
#         [245, 222, 200],
#         [245, 222, 200]],
#
#        ...,
#
#        [[ 90, 168, 174],
#         [102, 180, 186],
#         [112, 190, 196],
#         ...,
#         [ 74, 149, 147],
#         [ 81, 156, 154],
#         [ 98, 173, 171]],
#
#        [[ 92, 170, 176],
#         [ 99, 180, 185],
#         [114, 195, 200],
#         ...,
#         [ 58, 133, 131],
#         [ 50, 125, 123],
#         [ 68, 143, 141]],
#
#        [[ 90, 171, 174],
#         [ 86, 169, 171],
#         [107, 190, 192],
#         ...,
#         [ 75, 150, 148],
#         [ 57, 132, 130],
#         [ 92, 167, 165]]], dtype=uint8)

# %% [markdown]
# - matplotlibe channel--> Always give the channel ( R G B) || red, green, blue
# - opencv channel --> (B G R) || blue , green , red

# %%
fix_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(fix_img)

# %%
img_gray = cv2.imread(r'C:\Users\mirza\Desktop\videos\elephant.jpeg',cv2.IMREAD_GRAYSCALE)

# %%
img_gray.shape # it dont have 3 channel now
# Out:
# (1308, 736)

# %%
img_gray
# Out:
# array([[123, 123, 123, ..., 127, 127, 128],
#        [123, 123, 123, ..., 127, 127, 128],
#        [123, 123, 123, ..., 127, 127, 127],
#        ...,
#        [ 76,  73,  70, ...,  75,  71,  71],
#        [ 74,  72,  69, ...,  76,  71,  69],
#        [ 72,  70,  68, ...,  77,  71,  66]], dtype=uint8)

# %%
img_gray.min()
# Out:
# 0

# %%
img_gray.max()
# Out:
# 253

# %%
plt.imshow(img_gray)

# %%
plt.imshow(img_gray, cmap='gray')

# %%
plt.imshow(img_gray, cmap = 'magma') # try with green

# %%
#plt.imshow(img_gray, cmap = 'green')
plt.imshow(img_gray, cmap = 'Accent')

# %%
plt.imshow(img)

# %%
plt.imshow(fix_img)

# %%
fix_img.shape
# Out:
# (845, 564, 3)

# %%
fix_img_1 = cv2.resize(fix_img,(600,500)) # 600 -width & 500- height

# %%
plt.imshow(fix_img_1)

# %%
fix_img.shape
# Out:
# (845, 564, 3)

# %%
w_ratio = 0.3
h_ratio = 0.3

# %%
fix_img_2 = cv2.resize(fix_img,(0,0), fix_img, w_ratio, h_ratio)

# %%
fix_img_2.shape # 50% of the fix_img shape
# Out:
# (254, 169, 3)

# %%
plt.imshow(fix_img_2)

# %%
plt.imshow(fix_img)

# %%
img3 = cv2.flip(fix_img_2,0)
plt.imshow(img3)

# %%
cv2.imwrite('new generate image.jpg',img3)
# Out:
# True
